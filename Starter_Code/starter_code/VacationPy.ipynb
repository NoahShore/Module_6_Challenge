# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("..//output_data//cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 0        0  nikolayevsk-on-amure -37.0676  -12.3116     60.19        91
# 1        1  nikolayevsk-on-amure -49.3500   70.2167     41.05        84
# 2        2  nikolayevsk-on-amure  63.7506  -68.5145      8.33        72
# 3        3  nikolayevsk-on-amure  64.0049  -22.5624     39.63        81
# 4        4  nikolayevsk-on-amure  45.7625  106.2708     -3.12        90
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       15.12      SH  1702525746
# 1          75       43.73      TF  1702525745
# 2          75        5.75      CA  1702525724
# 3          75       48.34      IS  1702525754
# 4         100       14.99      MN  1702525985

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color = "City"
)

# Display the map
map_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_ideal_df = city_data_df[(city_data_df["Max Temp"] < 80)& 
                             (city_data_df["Max Temp"] > 60) &
                             (city_data_df["Wind Speed"] < 10) &
                            (city_data_df["Humidity"] < 60) &
                            (city_data_df["Humidity"] > 20)]

# Drop any rows with null values
city_ideal_df.dropna()

# Display sample data
city_ideal_df
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 28        28  nikolayevsk-on-amure   6.4965    2.6036     74.46        55
# 33        33  nikolayevsk-on-amure  10.6333   -8.6833     65.53        23
# 34        34  nikolayevsk-on-amure  11.5000   -3.5167     65.19        23
# 36        36  nikolayevsk-on-amure  23.7833   86.7167     69.89        35
# 39        39  nikolayevsk-on-amure -43.0167  147.3167     70.74        59
# 87        87  nikolayevsk-on-amure   9.5221   45.5336     63.95        58
# 102      102  nikolayevsk-on-amure  25.5198   90.2201     68.99        44
# 104      104  nikolayevsk-on-amure  32.6578 -114.4119     60.28        35
# 108      108  nikolayevsk-on-amure  29.0667 -110.9667     67.01        49
# 116      116  nikolayevsk-on-amure  32.2217   70.3793     61.84        29
# 132      132  nikolayevsk-on-amure  29.8500   80.5333     60.19        23
# 159      159  nikolayevsk-on-amure  29.9833   75.3833     62.28        24
# 176      176  nikolayevsk-on-amure  18.7000 -103.6583     78.01        55
# 192      192  nikolayevsk-on-amure  27.9167   96.1667     69.31        57
# 194      194  nikolayevsk-on-amure  27.7167   81.9333     64.18        42
# 235      235  nikolayevsk-on-amure  19.9333 -105.2500     74.25        58
# 262      262  nikolayevsk-on-amure -35.7317  174.3239     70.74        50
# 282      282  nikolayevsk-on-amure  19.9000   86.1167     73.80        50
# 317      317  nikolayevsk-on-amure  32.0303  120.8747     66.00        50
# 349      349  nikolayevsk-on-amure  21.9667   71.5667     74.01        34
# 355      355  nikolayevsk-on-amure  27.0500   76.9333     65.50        40
# 372      372  nikolayevsk-on-amure  20.9310  -17.0347     69.78        40
# 385      385  nikolayevsk-on-amure -11.0483  -45.1931     77.95        48
# 396      396  nikolayevsk-on-amure -23.9631  -46.3919     77.27        26
# 435      435  nikolayevsk-on-amure  17.9583 -102.2000     79.63        55
# 440      440  nikolayevsk-on-amure -13.3433  -44.6367     71.62        43
# 484      484  nikolayevsk-on-amure  26.8000   82.2000     65.26        31
# 491      491  nikolayevsk-on-amure  35.7333  140.8333     61.29        52
# 517      517  nikolayevsk-on-amure  28.2833   74.3167     65.12        24
# 554      554  nikolayevsk-on-amure -21.9833   16.9167     68.72        36
# 569      569  nikolayevsk-on-amure   9.1333    4.8333     68.43        27
# 574      574  nikolayevsk-on-amure  16.6614   -9.6149     65.08        23
# 578      578  nikolayevsk-on-amure  34.0556 -117.1825     60.48        37
# 581      581  nikolayevsk-on-amure  17.9583 -102.2000     79.63        55
#
#      Cloudiness  Wind Speed Country        Date
# 28            1        3.51      BJ  1702526013
# 33            0        4.54      GN  1702526019
# 34            0        5.70      BF  1702526020
# 36           46        4.16      IN  1702526023
# 39           81        3.00      AU  1702525757
# 87           68        9.19      SO  1702526086
# 102           0        1.14      IN  1702525755
# 104           0        4.61      US  1702526107
# 108           0        3.40      MX  1702526054
# 116         100        2.71      PK  1702526122
# 132           7        2.82      IN  1702526143
# 159          49        4.21      IN  1702526178
# 176         100        3.36      MX  1702525767
# 192          17        3.36      IN  1702526218
# 194           0        3.29      IN  1702526221
# 235         100        2.13      MX  1702525909
# 262           5        9.69      NZ  1702526304
# 282         100        6.73      IN  1702526327
# 317          10        4.47      CN  1702526367
# 349          17        9.53      IN  1702526417
# 355          28        2.46      IN  1702526428
# 372           0        8.05      MR  1702526455
# 385          74        3.49      BR  1702526472
# 396          57        2.48      BR  1702526464
# 435          97        3.98      MX  1702526547
# 440           3        3.69      BR  1702526553
# 484           0        5.79      IN  1702526610
# 491          57        5.75      JP  1702526620
# 517          23        6.78      IN  1702526652
# 554         100        2.57     NaN  1702526700
# 569           5        2.75      NG  1702526720
# 574          80        9.62      MR  1702526728
# 578           0        1.99      US  1702526733
# 581          97        3.98      MX  1702526737

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_ideal_df[['City','Country','Lat','Lng','Humidity']].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                      City Country      Lat       Lng  Humidity Hotel Name
# 28   nikolayevsk-on-amure      BJ   6.4965    2.6036        55
# 33   nikolayevsk-on-amure      GN  10.6333   -8.6833        23
# 34   nikolayevsk-on-amure      BF  11.5000   -3.5167        23
# 36   nikolayevsk-on-amure      IN  23.7833   86.7167        35
# 39   nikolayevsk-on-amure      AU -43.0167  147.3167        59
# 87   nikolayevsk-on-amure      SO   9.5221   45.5336        58
# 102  nikolayevsk-on-amure      IN  25.5198   90.2201        44
# 104  nikolayevsk-on-amure      US  32.6578 -114.4119        35
# 108  nikolayevsk-on-amure      MX  29.0667 -110.9667        49
# 116  nikolayevsk-on-amure      PK  32.2217   70.3793        29
# 132  nikolayevsk-on-amure      IN  29.8500   80.5333        23
# 159  nikolayevsk-on-amure      IN  29.9833   75.3833        24
# 176  nikolayevsk-on-amure      MX  18.7000 -103.6583        55
# 192  nikolayevsk-on-amure      IN  27.9167   96.1667        57
# 194  nikolayevsk-on-amure      IN  27.7167   81.9333        42
# 235  nikolayevsk-on-amure      MX  19.9333 -105.2500        58
# 262  nikolayevsk-on-amure      NZ -35.7317  174.3239        50
# 282  nikolayevsk-on-amure      IN  19.9000   86.1167        50
# 317  nikolayevsk-on-amure      CN  32.0303  120.8747        50
# 349  nikolayevsk-on-amure      IN  21.9667   71.5667        34
# 355  nikolayevsk-on-amure      IN  27.0500   76.9333        40
# 372  nikolayevsk-on-amure      MR  20.9310  -17.0347        40
# 385  nikolayevsk-on-amure      BR -11.0483  -45.1931        48
# 396  nikolayevsk-on-amure      BR -23.9631  -46.3919        26
# 435  nikolayevsk-on-amure      MX  17.9583 -102.2000        55
# 440  nikolayevsk-on-amure      BR -13.3433  -44.6367        43
# 484  nikolayevsk-on-amure      IN  26.8000   82.2000        31
# 491  nikolayevsk-on-amure      JP  35.7333  140.8333        52
# 517  nikolayevsk-on-amure      IN  28.2833   74.3167        24
# 554  nikolayevsk-on-amure     NaN -21.9833   16.9167        36
# 569  nikolayevsk-on-amure      NG   9.1333    4.8333        27
# 574  nikolayevsk-on-amure      MR  16.6614   -9.6149        23
# 578  nikolayevsk-on-amure      US  34.0556 -117.1825        37
# 581  nikolayevsk-on-amure      MX  17.9583 -102.2000        55

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# nikolayevsk-on-amure - nearest hotel: Hôtel 6500 CFA
# nikolayevsk-on-amure - nearest hotel: Hôtel Prince
# nikolayevsk-on-amure - nearest hotel: Baobab
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: Villa Howden
# nikolayevsk-on-amure - nearest hotel: Liiban hotel burco ( ENG:Shibiin )
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: Comfort Inn
# nikolayevsk-on-amure - nearest hotel: Lucerna
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: अपि हिमाल होटल
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: Hotel Hacienda Vieja Tomatlan
# nikolayevsk-on-amure - nearest hotel: Grand Hotel
# nikolayevsk-on-amure - nearest hotel: Hotel Sun Village
# nikolayevsk-on-amure - nearest hotel: Sakula Mansyon
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: Motel Gangaur
# nikolayevsk-on-amure - nearest hotel: Hotel valencia
# nikolayevsk-on-amure - nearest hotel: Pousada Universo - Formosa do Rio Preto BA
# nikolayevsk-on-amure - nearest hotel: Pousada Vitória
# nikolayevsk-on-amure - nearest hotel: Hotel Sol del Pacífico
# nikolayevsk-on-amure - nearest hotel: Pousada Silva
# nikolayevsk-on-amure - nearest hotel: Birla Dharamshala
# nikolayevsk-on-amure - nearest hotel: 大新旅館
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: Okahandja Country Hotel
# nikolayevsk-on-amure - nearest hotel: No hotel found
# nikolayevsk-on-amure - nearest hotel: فندق العيون
# nikolayevsk-on-amure - nearest hotel: Ayres Hotel Redlands
# nikolayevsk-on-amure - nearest hotel: Hotel Sol del Pacífico
#                      City Country      Lat       Lng  Humidity  \
# 28   nikolayevsk-on-amure      BJ   6.4965    2.6036        55
# 33   nikolayevsk-on-amure      GN  10.6333   -8.6833        23
# 34   nikolayevsk-on-amure      BF  11.5000   -3.5167        23
# 36   nikolayevsk-on-amure      IN  23.7833   86.7167        35
# 39   nikolayevsk-on-amure      AU -43.0167  147.3167        59
# 87   nikolayevsk-on-amure      SO   9.5221   45.5336        58
# 102  nikolayevsk-on-amure      IN  25.5198   90.2201        44
# 104  nikolayevsk-on-amure      US  32.6578 -114.4119        35
# 108  nikolayevsk-on-amure      MX  29.0667 -110.9667        49
# 116  nikolayevsk-on-amure      PK  32.2217   70.3793        29
# 132  nikolayevsk-on-amure      IN  29.8500   80.5333        23
# 159  nikolayevsk-on-amure      IN  29.9833   75.3833        24
# 176  nikolayevsk-on-amure      MX  18.7000 -103.6583        55
# 192  nikolayevsk-on-amure      IN  27.9167   96.1667        57
# 194  nikolayevsk-on-amure      IN  27.7167   81.9333        42
# 235  nikolayevsk-on-amure      MX  19.9333 -105.2500        58
# 262  nikolayevsk-on-amure      NZ -35.7317  174.3239        50
# 282  nikolayevsk-on-amure      IN  19.9000   86.1167        50
# 317  nikolayevsk-on-amure      CN  32.0303  120.8747        50
# 349  nikolayevsk-on-amure      IN  21.9667   71.5667        34
# 355  nikolayevsk-on-amure      IN  27.0500   76.9333        40
# 372  nikolayevsk-on-amure      MR  20.9310  -17.0347        40
# 385  nikolayevsk-on-amure      BR -11.0483  -45.1931        48
# 396  nikolayevsk-on-amure      BR -23.9631  -46.3919        26
# 435  nikolayevsk-on-amure      MX  17.9583 -102.2000        55
# 440  nikolayevsk-on-amure      BR -13.3433  -44.6367        43
# 484  nikolayevsk-on-amure      IN  26.8000   82.2000        31
# 491  nikolayevsk-on-amure      JP  35.7333  140.8333        52
# 517  nikolayevsk-on-amure      IN  28.2833   74.3167        24
# 554  nikolayevsk-on-amure     NaN -21.9833   16.9167        36
# 569  nikolayevsk-on-amure      NG   9.1333    4.8333        27
# 574  nikolayevsk-on-amure      MR  16.6614   -9.6149        23
# 578  nikolayevsk-on-amure      US  34.0556 -117.1825        37
# 581  nikolayevsk-on-amure      MX  17.9583 -102.2000        55
#
#                                      Hotel Name
# 28                               Hôtel 6500 CFA
# 33                                 Hôtel Prince
# 34                                       Baobab
# 36                               No hotel found
# 39                                 Villa Howden
# 87           Liiban hotel burco ( ENG:Shibiin )
# 102                              No hotel found
# 104                                 Comfort Inn
# 108                                     Lucerna
# 116                              No hotel found
# 132                              अपि हिमाल होटल
# 159                              No hotel found
# 176                              No hotel found
# 192                              No hotel found
# 194                              No hotel found
# 235               Hotel Hacienda Vieja Tomatlan
# 262                                 Grand Hotel
# 282                           Hotel Sun Village
# 317                              Sakula Mansyon
# 349                              No hotel found
# 355                               Motel Gangaur
# 372                              Hotel valencia
# 385  Pousada Universo - Formosa do Rio Preto BA
# 396                             Pousada Vitória
# 435                      Hotel Sol del Pacífico
# 440                               Pousada Silva
# 484                           Birla Dharamshala
# 491                                        大新旅館
# 517                              No hotel found
# 554                     Okahandja Country Hotel
# 569                              No hotel found
# 574                                 فندق العيون
# 578                        Ayres Hotel Redlands
# 581                      Hotel Sol del Pacífico

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color = "City",
    hover_cols = ['Hotel Name','Country']
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
